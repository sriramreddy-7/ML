# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramreddy-7/ML/blob/main/BCS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/breast_cancer_survival.csv')

# %%
df
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status
# ...

# %%
df['Gender'].unique()
# Out:
# array(['FEMALE', 'MALE'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Protein1               0
# Protein2               0
# Protein3               0
# Protein4               0
# Tumour_Stage           0
# Histology              0
# ER status              0
# PR status              0
# HER2 status            0
# Surgery_type           0
# Date_of_Surgery        0
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Date_of_Surgery']=pd.to_datetime(df['Date_of_Surgery'])
# Out:
# <ipython-input-10-e8616e519f71>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_of_Surgery']=pd.to_datetime(df['Date_of_Surgery'])

# %%
df['Date_of_Surgery']
# Out:
# 0     2018-05-20
# 1     2018-04-26
# 2     2018-08-24
# 3     2018-11-16
# 4     2018-12-12
#          ...
# 329   2019-01-15
# 330   2018-07-25
# 331   2019-03-26
# 332   2018-11-26
# 333   2019-02-04
# Name: Date_of_Surgery, Length: 334, dtype: datetime64[ns]

# %%
df['Date_of_Last_Visi']=pd.to_datetime(df['Date_of_Last_Visit'])
# Out:
# <ipython-input-14-70b24b68ef28>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_of_Last_Visi']=pd.to_datetime(df['Date_of_Last_Visit'])

# %%
df['Date_of_Surgery'] = pd.to_datetime(df['Date_of_Surgery'])
df['Date_of_Last_Visit'] = pd.to_datetime(df['Date_of_Last_Visit'])
# Out:
# <ipython-input-16-eace3e0483d5>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_of_Last_Visit'] = pd.to_datetime(df['Date_of_Last_Visit'])

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status Date_of_Last_Visi
# ...

# %%
df['difference']=(df['Date_of_Last_Visit']-df['Date_of_Surgery']).dt.days

# %%
df['difference']=df['difference']/30

# %%
df['difference']
# Out:
# 0       3.266667
# 1       9.133333
# 2      19.766667
# 3      20.666667
# 4       0.800000
#          ...
# 329    14.566667
# 330     9.066667
# 331     6.633333
# 332     0.300000
# 333     6.233333
# Name: difference, Length: 334, dtype: float64

# %%
df.drop(['Date_of_Surgery','Date_of_Last_Visit','Date_of_Last_Visi'],axis=1)
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
df['difference'].isnull().sum()
# Out:
# 17

# %%
df['difference'].fillna(df['difference'].mean(),inplace=True)

# %%
df['difference']
# Out:
# 0       3.266667
# 1       9.133333
# 2      19.766667
# 3      20.666667
# 4       0.800000
#          ...
# 329    14.566667
# 330     9.066667
# 331     6.633333
# 332     0.300000
# 333     6.233333
# Name: difference, Length: 334, dtype: float64

# %%
df['difference'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status Date_of_Last_Visi  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Gender']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 329    0
# 330    0
# 331    0
# 332    0
# 333    0
# Name: Gender, Length: 334, dtype: int64

# %%
df['Tumour_Stage']=le.fit_transform(df['Tumour_Stage'])

# %%
df['Histology']=le.fit_transform(df['Histology'])

# %%
df['ER status']=le.fit_transform(df['ER status'])

# %%
df['PR status']=le.fit_transform(df['PR status'])

# %%
df['HER2 status']=le.fit_transform(df['HER2 status'])

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0   42       0   0.95256   2.15000  0.007972 -0.048340             1
# 1   54       0   0.00000   1.38020 -0.498030 -0.507320             1
# 2   63       0  -0.52303   1.76400 -0.370190  0.010815             1
# 3   78       0  -0.87618   0.12943 -0.370380  0.132190             0
# 4   42       0   0.22611   1.74910 -0.543970 -0.390210             1
#
#    Histology  ER status  PR status  HER2 status Surgery_type Date_of_Surgery  \
# 0          0          0          0            0        Other      2018-05-20
# 1          0          0          0            0        Other      2018-04-26
# 2          0          0          0            0   Lumpectomy      2018-08-24
# 3          0          0          0            0        Other      2018-11-16
# 4          0          0          0            1   Lumpectomy      2018-12-12
#
#   Date_of_Last_Visit Patient_Status Date_of_Last_Visi  difference
# ...

# %%
df['Surgery_type']=le.fit_transform(df['Surgery_type'])
df['Patient_Status']=le.fit_transform(df['Patient_Status'])

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0   42       0   0.95256   2.15000  0.007972 -0.048340             1
# 1   54       0   0.00000   1.38020 -0.498030 -0.507320             1
# 2   63       0  -0.52303   1.76400 -0.370190  0.010815             1
# 3   78       0  -0.87618   0.12943 -0.370380  0.132190             0
# 4   42       0   0.22611   1.74910 -0.543970 -0.390210             1
#
#    Histology  ER status  PR status  HER2 status  Surgery_type Date_of_Surgery  \
# 0          0          0          0            0             2      2018-05-20
# 1          0          0          0            0             2      2018-04-26
# 2          0          0          0            0             0      2018-08-24
# 3          0          0          0            0             2      2018-11-16
# 4          0          0          0            1             0      2018-12-12
#
#   Date_of_Last_Visit  Patient_Status Date_of_Last_Visi  difference
# ...

# %%
df.drop(['Date_of_Surgery','Date_of_Last_Visit','Date_of_Last_Visi'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0   42       0   0.95256   2.15000  0.007972 -0.048340             1
# 1   54       0   0.00000   1.38020 -0.498030 -0.507320             1
# 2   63       0  -0.52303   1.76400 -0.370190  0.010815             1
# 3   78       0  -0.87618   0.12943 -0.370380  0.132190             0
# 4   42       0   0.22611   1.74910 -0.543970 -0.390210             1
#
#    Histology  ER status  PR status  HER2 status  Surgery_type  Patient_Status  \
# 0          0          0          0            0             2               0
# 1          0          0          0            0             2               1
# 2          0          0          0            0             0               0
# 3          0          0          0            0             2               0
# 4          0          0          0            1             0               0
#
#    difference
# 0    3.266667
# 1    9.133333
# 2   19.766667
# 3   20.666667
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Gender            0
# Protein1          0
# Protein2          0
# Protein3          0
# Protein4          0
# Tumour_Stage      0
# Histology         0
# ER status         0
# PR status         0
# HER2 status       0
# Surgery_type      0
# Patient_Status    0
# difference        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                      Age    Gender  Protein1  Protein2  Protein3  Protein4  \
# Age             1.000000  0.024362 -0.050638 -0.021542 -0.039686  0.094214
# Gender          0.024362  1.000000  0.150601  0.000715 -0.017694 -0.014290
# Protein1       -0.050638  0.150601  1.000000  0.238141 -0.129482  0.280343
# Protein2       -0.021542  0.000715  0.238141  1.000000 -0.415825  0.088239
# Protein3       -0.039686 -0.017694 -0.129482 -0.415825  1.000000  0.065316
# Protein4        0.094214 -0.014290  0.280343  0.088239  0.065316  1.000000
# Tumour_Stage   -0.167654  0.033369 -0.050201 -0.051786  0.038271 -0.037264
# Histology      -0.108969  0.032733  0.069494  0.005117 -0.001745  0.017252
# ER status            NaN       NaN       NaN       NaN       NaN       NaN
# PR status            NaN       NaN       NaN       NaN       NaN       NaN
# HER2 status    -0.069589 -0.033949 -0.029940 -0.012203 -0.019827  0.003046
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.countplot(y=df['Tumour_Stage'])
# Out:
# <Axes: xlabel='count', ylabel='Tumour_Stage'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['Patient_Status'],axis=1)
y=df['Patient_Status']

# %%
x
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0     42       0  0.952560   2.15000  0.007972 -0.048340             1
# 1     54       0  0.000000   1.38020 -0.498030 -0.507320             1
# 2     63       0 -0.523030   1.76400 -0.370190  0.010815             1
# 3     78       0 -0.876180   0.12943 -0.370380  0.132190             0
# 4     42       0  0.226110   1.74910 -0.543970 -0.390210             1
# ..   ...     ...       ...       ...       ...       ...           ...
# 329   59       0  0.024598   1.40050  0.024751  0.280320             1
# 330   41       0  0.100120  -0.46547  0.472370 -0.523870             0
# 331   54       0  0.753820   1.64250 -0.332850  0.857860             1
# 332   74       0  0.972510   1.42680 -0.366570 -0.107820             1
# 333   66       0  0.286380   1.39980  0.318830  0.836050             1
#
#      Histology  ER status  PR status  HER2 status  Surgery_type  difference
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 329    0
# 330    0
# 331    1
# 332    0
# 333    1
# Name: Patient_Status, Length: 334, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred)

# %%
print(100*acc)
# Out:
# 77.61194029850746

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.87        52
#            1       0.00      0.00      0.00        12
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.78        67
#    macro avg       0.26      0.33      0.29        67
# weighted avg       0.60      0.78      0.68        67
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[52  0  0]
#  [12  0  0]
#  [ 3  0  0]]
