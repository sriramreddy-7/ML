# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramreddy-7/ML/blob/main/Branch_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/TSEAMCET_2023.csv')

# %%
df
# Out:
#       Inst Code                                   Institution Name Branch  \
# 0          JNTH  JNTUH UNIVERSITY COLLEGE OF ENGG SCI AND TECH ...    CSE
# 1          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSD
# 2          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSI
# 3          CBIT         CHAITANYA BHARATHI INSTITUTE OF TECHNOLOGY    CSE
# 4          OUCE                     O U COLLEGE OF ENGG  HYDERABAD    CSE
# ...         ...                                                ...    ...
# 69397      DCET       DECCAN COLLEGE OF ENGINEERING AND TECHNOLOGY    MEC
# 69398      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    CSD
# 69399      LRDS  LORDS INSTITUTE OF ENGINEERING AND TECHNOLOGY ...     CS
# 69400      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    AIM
# 69401      SWET         SHADHAN WOMENS COLL OF ENGG AND TECHNOLOGY    CSE
#
#       Hall Ticket No    Rank               Candidate Name Gender Region  \
# 0         2324A01913     306              YARAGANI MAHESH      M     OU
# 1         2325C04135     491      DESHAGANI CHENNAKESHAVA      M     OU
# 2         2325A07188     511  GOPIREDDY GUNAVARDHAN REDDY      M     OU
# 3         2321R05046     524          NALAMOTHU TARAK RAM      M     AU
# 4         2321C01088     590   RAVULA JAYANTH KUMAR REDDY      M     OU
# ...              ...     ...                          ...    ...    ...
# 69397      900000484  300144     MOHD ALI ASGHAR FAROOQUI      M     OU
# 69398      900000596  300146                MOHAMMED ZAID      M     OU
# 69399      900000464  300147         MOHAMMED ABDUL WAJID      M     OU
# 69400      900000438  300149              MOHAMMED KHALIL      M     OU
# 69401      900000555  300150               AFREEN SULTANA      F     OU
#
#       Caste_       Seat_Cat
# 0       BC_B      OC_GEN_UR
# 1       BC_B    BC_B_GEN_OU
# 2         OC  OC_PHO_GEN_OU
# 3         OC      OC_GEN_UR
# 4         OC      OC_GEN_UR
# ...      ...            ...
# 69397   BC_E     MUS_GEN_OU
# 69398   BC_E     MUS_GEN_UR
# 69399   BC_E     MUS_GEN_OU
# 69400   BC_E     MUS_GEN_OU
# 69401   BC_E   MUS_GIRLS_OU
#
# [69402 rows x 10 columns]

# %%
df.isna()
# Out:
#        Inst Code  Institution Name  Branch  Hall Ticket No   Rank  \
# 0          False             False   False           False  False
# 1          False             False   False           False  False
# 2          False             False   False           False  False
# 3          False             False   False           False  False
# 4          False             False   False           False  False
# ...          ...               ...     ...             ...    ...
# 69397      False             False   False           False  False
# 69398      False             False   False           False  False
# 69399      False             False   False           False  False
# 69400      False             False   False           False  False
# 69401      False             False   False           False  False
#
#        Candidate Name  Gender  Region  Caste_  Seat_Cat
# 0               False   False   False   False     False
# 1               False   False   False   False     False
# 2               False   False   False   False     False
# 3               False   False   False   False     False
# 4               False   False   False   False     False
# ...               ...     ...     ...     ...       ...
# 69397           False   False   False   False     False
# 69398           False   False   False   False     False
# 69399           False   False   False   False     False
# 69400           False   False   False   False     False
# 69401           False   False   False   False     False
#
# [69402 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# Inst Code           0
# Institution Name    0
# Branch              0
# Hall Ticket No      0
# Rank                0
# Candidate Name      0
# Gender              0
# Region              0
# Caste_              0
# Seat_Cat            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Inst Code                                   Institution Name Branch  \
# 0          JNTH  JNTUH UNIVERSITY COLLEGE OF ENGG SCI AND TECH ...    CSE
# 1          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSD
# 2          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSI
# 3          CBIT         CHAITANYA BHARATHI INSTITUTE OF TECHNOLOGY    CSE
# 4          OUCE                     O U COLLEGE OF ENGG  HYDERABAD    CSE
# ...         ...                                                ...    ...
# 69397      DCET       DECCAN COLLEGE OF ENGINEERING AND TECHNOLOGY    MEC
# 69398      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    CSD
# 69399      LRDS  LORDS INSTITUTE OF ENGINEERING AND TECHNOLOGY ...     CS
# 69400      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    AIM
# 69401      SWET         SHADHAN WOMENS COLL OF ENGG AND TECHNOLOGY    CSE
#
#       Hall Ticket No    Rank               Candidate Name Gender Region  \
# 0         2324A01913     306              YARAGANI MAHESH      M     OU
# 1         2325C04135     491      DESHAGANI CHENNAKESHAVA      M     OU
# 2         2325A07188     511  GOPIREDDY GUNAVARDHAN REDDY      M     OU
# 3         2321R05046     524          NALAMOTHU TARAK RAM      M     AU
# 4         2321C01088     590   RAVULA JAYANTH KUMAR REDDY      M     OU
# ...              ...     ...                          ...    ...    ...
# 69397      900000484  300144     MOHD ALI ASGHAR FAROOQUI      M     OU
# 69398      900000596  300146                MOHAMMED ZAID      M     OU
# 69399      900000464  300147         MOHAMMED ABDUL WAJID      M     OU
# 69400      900000438  300149              MOHAMMED KHALIL      M     OU
# 69401      900000555  300150               AFREEN SULTANA      F     OU
#
#       Caste_       Seat_Cat
# 0       BC_B      OC_GEN_UR
# 1       BC_B    BC_B_GEN_OU
# 2         OC  OC_PHO_GEN_OU
# 3         OC      OC_GEN_UR
# 4         OC      OC_GEN_UR
# ...      ...            ...
# 69397   BC_E     MUS_GEN_OU
# 69398   BC_E     MUS_GEN_UR
# 69399   BC_E     MUS_GEN_OU
# 69400   BC_E     MUS_GEN_OU
# 69401   BC_E   MUS_GIRLS_OU
#
# [69402 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# Inst Code           0
# Institution Name    0
# Branch              0
# Hall Ticket No      0
# Rank                0
# Candidate Name      0
# Gender              0
# Region              0
# Caste_              0
# Seat_Cat            0
# dtype: int64

# %%
df.drop(['Hall Ticket No','Candidate Name'],axis=1,inplace=True)

# %%
df
# Out:
#       Inst Code                                   Institution Name Branch  \
# 0          JNTH  JNTUH UNIVERSITY COLLEGE OF ENGG SCI AND TECH ...    CSE
# 1          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSD
# 2          MVSR           M V S R ENGINEERING COLLEGE (AUTONOMOUS)    CSI
# 3          CBIT         CHAITANYA BHARATHI INSTITUTE OF TECHNOLOGY    CSE
# 4          OUCE                     O U COLLEGE OF ENGG  HYDERABAD    CSE
# ...         ...                                                ...    ...
# 69397      DCET       DECCAN COLLEGE OF ENGINEERING AND TECHNOLOGY    MEC
# 69398      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    CSD
# 69399      LRDS  LORDS INSTITUTE OF ENGINEERING AND TECHNOLOGY ...     CS
# 69400      SCET  SHADHAN COLL OF ENGINEERING AND TECHNOLOGY (AU...    AIM
# 69401      SWET         SHADHAN WOMENS COLL OF ENGG AND TECHNOLOGY    CSE
#
#          Rank Gender Region Caste_       Seat_Cat
# 0         306      M     OU   BC_B      OC_GEN_UR
# 1         491      M     OU   BC_B    BC_B_GEN_OU
# 2         511      M     OU     OC  OC_PHO_GEN_OU
# 3         524      M     AU     OC      OC_GEN_UR
# 4         590      M     OU     OC      OC_GEN_UR
# ...       ...    ...    ...    ...            ...
# 69397  300144      M     OU   BC_E     MUS_GEN_OU
# 69398  300146      M     OU   BC_E     MUS_GEN_UR
# 69399  300147      M     OU   BC_E     MUS_GEN_OU
# 69400  300149      M     OU   BC_E     MUS_GEN_OU
# 69401  300150      F     OU   BC_E   MUS_GIRLS_OU
#
# [69402 rows x 8 columns]

# %%
df.shape
# Out:
# (69402, 8)

# %%
df['Branch'].value_counts()
# Out:
# Branch
# CSE         21770
# CSM         10678
# ECE          9339
# CSD          6806
# INF          4716
#             ...
# S)CIV           6
# S)MEC           5
# PHE             3
# MMT             3
# ENGPHGM)        1
# Name: count, Length: 81, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
from sklearn.model_selection import train_test_split

# %%
for col in df.columns:
  if df[col].dtype==object:
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#        Inst Code  Institution Name  Branch    Rank  Gender  Region  Caste_  \
# 0             68                65      17     306       1       2       1
# 1            121                96      16     491       1       2       1
# 2            121                96      19     511       1       2       5
# 3             24                26      17     524       1       0       5
# 4            129               124      17     590       1       2       5
# ...          ...               ...     ...     ...     ...     ...     ...
# 69397         39                40      44  300144       1       2       4
# 69398        140               137      16  300146       1       2       4
# 69399         97                93      12  300147       1       2       4
# 69400        140               137       3  300149       1       2       4
# 69401        166               138      17  300150       0       2       4
#
#        Seat_Cat
# 0           129
# 1            28
# 2           147
# 3           129
# 4           129
# ...         ...
# 69397       117
# 69398       118
# 69399       117
# 69400       117
# 69401       119
#
# [69402 rows x 8 columns]

# %%
df['Branch'].value_counts()
# Out:
# Branch
# 17    21770
# 20    10678
# 26     9339
# 16     6806
# 42     4716
#       ...
# 67        6
# 72        5
# 64        3
# 47        3
# 38        1
# Name: count, Length: 81, dtype: int64

# %%
x=df.drop('Branch',axis=1)
y=df['Branch']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Initialize the classifier
clf = DecisionTreeClassifier()

# Train the model
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 42.89%

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
RC_model=RandomForestClassifier()

# %%
clf2 = RandomForestClassifier(n_estimators=500, random_state=42)

# %%
clf2.fit(X_train, y_train)
y_pred = clf2.predict(X_test)
accu = accuracy_score(y_test, y_pred)

# %%
print(accu*100)
# Out:
# 47.28045529860961

# %%
knn = KNeighborsClassifier(n_neighbors=999)

# Fit the classifier to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=999)

# %%
# Predict on the test set
y_pred = knn.predict(X_test)

# %%
# Predict on the test set
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.31

# %%
# Print classification report
print(classification_report(y_test, y_pred))
# Print confusion matrix
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0